# %% [markdown]
# # 🧠 SESSION 1: Database Thinking for Data Analysts
#
# ⏱️ Time: **~1–1.5 hours**
# (Level: **Beginner → Analyst mindset**)
#
# ---
#
# ## 🔰 Why This Session Is CRITICAL
#
# Most beginners fail SQL because they:
#
# * Memorize queries ❌
# * Don’t understand **what a database actually is** ❌
#
# This session fixes that.
#
# By the end of Session 1, you will:
#
# * Think in **tables, rows, and questions**
# * Understand **why SQL exists**
# * Know **what analysts do with databases** (and what they don’t)
#
# ---
#
# ## 1️⃣ What Is a Database? (From Scratch)
#
# ### Simple Definition
#
# A **database** is a **structured place to store data** so that:
#
# * It is safe
# * It is fast to search
# * Many people can use it at the same time
#
# Think of a database as:
#
# > **Excel + rules + speed + scale**
#
# ---
#
# ### Real-World Analogy
#
# 📒 **Excel Sheet**
#
# * One file
# * Manual filtering
# * Breaks with large data
#
# 🗄️ **Database**
#
# * Thousands of tables
# * Millions of rows
# * Queried instantly using SQL
#
# ---
#
# ## 2️⃣ What Is a Table? (MOST IMPORTANT CONCEPT)
#
# A **table** is the core of everything in SQL.
#
# | Table Part | Meaning                        |
# | ---------- | ------------------------------ |
# | Column     | Attribute (name, salary, city) |
# | Row        | One complete record            |
# | Cell       | One value                      |
#
# ### Example: `employees` table
#
# | emp_id | name | department | salary | city   |
# | ------ | ---- | ---------- | ------ | ------ |
# | 1      | Amit | IT         | 60000  | Delhi  |
# | 2      | Sara | HR         | 50000  | Mumbai |
#
# 📌 **Analyst Rule**
#
# > Every SQL query is just a smart way of reading tables.
#
# ---
#
# ## 3️⃣ Rows vs Columns (Clear the Confusion)
#
# ### Columns
#
# * Describe **what kind of data**
# * Fixed structure
#
# Examples:
#
# * name
# * salary
# * city
#
# ### Rows
#
# * Actual data
# * Changes every day
#
# Example:
#
# * Amit, IT, 60000, Delhi
#
# 📌 Interview keyword:
# **“Each row represents one entity (employee/customer/order)”**
#
# ---
#
# ## 4️⃣ What Is a Primary Key?
#
# ### Definition
#
# A **Primary Key** is:
#
# * A column
# * With **unique values**
# * Used to identify each row
#
# ### Example
#
# `emp_id`
#
# Why it matters:
#
# * No duplicate rows
# * Faster searching
# * Used for joining tables later
#
# 📌 Analysts must **understand** this even if they don’t design databases.
#
# ---
#
# ## 5️⃣ What Is SQL (For Analysts)?
#
# SQL = **Structured Query Language**
#
# But for analysts:
#
# > SQL is a **question-asking language**
#
# ### Examples of Analyst Questions
#
# * Which employees earn more than 50,000?
# * Which city has the highest sales?
# * How many orders happened last month?
#
# SQL converts these questions into queries.
#
# ---
#
# ## 6️⃣ What Analysts Do vs What They Don’t
#
# ### ✅ Analysts DO
#
# * Read data (`SELECT`)
# * Filter data (`WHERE`)
# * Sort data (`ORDER BY`)
# * Summarize data (`GROUP BY` – later)
#
# ### ❌ Analysts usually DON’T
#
# * Tune servers
# * Manage backups
# * Configure memory
#
# 📌 This removes fear: **You are not becoming a DBA.**
#
# ---
#
# ## 7️⃣ What Is PostgreSQL?
#
# PostgreSQL is:
#
# * A **database software**
# * Stores data in tables
# * Understands SQL
# * Used by real companies
#
# pgAdmin is just a **tool to talk to PostgreSQL**.
#
# ---
#
# ## 8️⃣ How SQL Fits Into Data Analytics Workflow
#
# ### Typical Company Flow
#
# ```
# Database (PostgreSQL)
#         ↓
#       SQL
#         ↓
#      Pandas
#         ↓
#  Visualization
#         ↓
#    Business Decision
# ```
#
# 📌 SQL = **first step**, not last.
#
# ---
#
# ## 🧠 Analyst Mindset (VERY IMPORTANT)
#
# Always ask yourself:
#
# 1. What table has the data?
# 2. What does **one row represent**?
# 3. What columns answer my question?
#
# If you can answer these → SQL becomes easy.
#
# ---
#
# ## ✅ PRACTICE (Think, Don’t Code Yet)
#
# Answer in words (this builds foundations):
#
# 1. In a `students` table, what does **one row** represent?
# 2. What could be a **primary key** for an `orders` table?
# 3. If a company has 1 million customers, why is Excel a bad idea?
# 4. Which tool is better for:
#
#    * Storing data long-term?
#    * Asking questions quickly?
#
# ---
#
# ## 🎤 INTERVIEW QUESTIONS FROM SESSION 1
#
# ### Q1️⃣ What is a database?
#
# **Expected Answer:**
#
# > A database is a structured system used to store, manage, and retrieve large amounts of data efficiently using tables.
#
# ---
#
# ### Q2️⃣ What is the difference between a table and a database?
#
# **Expected Answer:**
#
# > A database is a collection of tables, while a table stores data in rows and columns.
#
# ---
#
# ### Q3️⃣ What does a row represent in a table?
#
# **Expected Answer:**
#
# > Each row represents one complete record, such as one employee or one order.
#
# ---
#
# ### Q4️⃣ What is a primary key and why is it important?
#
# **Expected Answer:**
#
# > A primary key uniquely identifies each row and prevents duplicate records.
#
# ---
#
# ### Q5️⃣ Why do data analysts use SQL?
#
# **Expected Answer:**
#
# > Analysts use SQL to efficiently extract, filter, and summarize data from databases before analysis.
#
# ---
