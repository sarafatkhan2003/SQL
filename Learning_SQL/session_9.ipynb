# %% [markdown]
# # 🧩 SESSION 9: Subqueries & Advanced Filtering
#
#
# 🎯 **Goal:**
#
# * Understand what subqueries are
# * Learn WHERE subqueries
# * Use IN, EXISTS, ANY, ALL
# * Compare subquery vs JOIN
# * Solve interview-level problems
#
# ---
#
# # 🔹 1️⃣ What Is a Subquery? (From Scratch)
#
#  **🔸 Simple Definition**
#
# A **subquery** is:
#
# > A query inside another query.
#
# It runs first and provides results to the outer query.
#
# ---
#
# **🔸 Basic Structure**
#
# ```sql
# SELECT column
# FROM table
# WHERE column = (
#     SELECT column
#     FROM table
# );
# ```
#
# 📌 Inner query runs first
# 📌 Outer query uses its result
#
# ---
#
# # 🔹 2️⃣ Data Reminder
#
# We use:
#
#  **customers**
#
# | customer_id | name | city |
#
#  **orders**
#
# | order_id | customer_id | amount | order_date |
#
# ---
#
# # 🔹 3️⃣ Subquery in WHERE (Single Value)
#
# ---
#
#  **Example 1: Find Customer Who Spent the Most**
#
# Step 1: Find maximum order amount
#
# ```sql
# SELECT MAX(amount) FROM orders;
# ```
#
# Step 2: Use subquery
#
# ```sql
# SELECT *
# FROM orders
# WHERE amount = (
#     SELECT MAX(amount) FROM orders
# );
# ```
#
# 📌 Inner query → gives max amount
# 📌 Outer query → finds row with that amount
#
# ---
#
# ### 🧪 Practice 1
#
# 1. Find order with lowest amount
# 2. Find customer who placed highest-value order
#
# ---
#
# # 🔹 4️⃣ Subquery Returning Multiple Values (IN)
#
# If subquery returns multiple rows, use `IN`.
#
# ---
#
# ## Example: Customers Who Placed Orders
#
# ```sql
# SELECT *
# FROM customers
# WHERE customer_id IN (
#     SELECT customer_id
#     FROM orders
# );
# ```
#
# 📌 Returns customers who appear in orders table.
#
# ---
#
# ### 🧪 Practice 2
#
# 1. Customers who never placed an order
# 2. Orders placed by customers from Delhi
#
# Hint:
# Use subquery inside WHERE.
#
# ---
#
# # 🔹 5️⃣ NOT IN (Be Careful)
#
# ```sql
# SELECT *
# FROM customers
# WHERE customer_id NOT IN (
#     SELECT customer_id FROM orders
# );
# ```
#
# 📌 Shows customers with no orders.
#
# ⚠️ Important:
# If subquery returns NULL, NOT IN can behave unexpectedly.
#
# We’ll fix that later using EXISTS.
#
# ---
#
# # 🔹 6️⃣ EXISTS (Very Important for Interviews)
#
# EXISTS checks:
#
# > Does a matching row exist?
#
# ---
#
# ## Example: Customers Who Have Orders
#
# ```sql
# SELECT *
# FROM customers c
# WHERE EXISTS (
#     SELECT 1
#     FROM orders o
#     WHERE o.customer_id = c.customer_id
# );
# ```
#
# 📌 EXISTS is often faster and safer than IN.
#
# ---
#
# ### Why SELECT 1?
#
# We don’t care about data, only existence.
#
# ---
#
# ### 🧪 Practice 3
#
# 1. Customers who have orders
# 2. Customers who have no orders (use NOT EXISTS)
#
# ---
#
# # 🔹 7️⃣ Correlated Subqueries (Advanced Concept)
#
# A correlated subquery:
#
# * Refers to outer query column
# * Runs once per row
#
# ---
#
# ## Example: Orders Above Customer’s Average
#
# ```sql
# SELECT *
# FROM orders o
# WHERE amount > (
#     SELECT AVG(amount)
#     FROM orders
#     WHERE customer_id = o.customer_id
# );
# ```
#
# 📌 For each order:
#
# * Calculate average for that customer
# * Compare
#
# This is interview-level thinking.
#
# ---
#
# ### 🧪 Practice 4
#
# 1. Find orders above overall average
# 2. Find customers who spent more than average spending
#
# ---
#
# # 🔹 8️⃣ ANY and ALL (Advanced Filtering)
#
# Rare but powerful.
#
# ---
#
# ## ANY Example
#
# ```sql
# SELECT *
# FROM orders
# WHERE amount > ANY (
#     SELECT amount FROM orders WHERE customer_id = 1
# );
# ```
#
# Meaning:
#
# * Greater than at least one value
#
# ---
#
# ## ALL Example
#
# ```sql
# SELECT *
# FROM orders
# WHERE amount > ALL (
#     SELECT amount FROM orders WHERE customer_id = 1
# );
# ```
#
# Meaning:
#
# * Greater than all values
#
# 📌 These are advanced but good to know.
#
# ---
#
# # 🔹 9️⃣ Subquery vs JOIN (Very Important)
#
# Many subqueries can be rewritten as JOINs.
#
# ---
#
# ## Example Using JOIN Instead of Subquery
#
# Subquery:
#
# ```sql
# SELECT *
# FROM customers
# WHERE customer_id IN (
#     SELECT customer_id FROM orders
# );
# ```
#
# JOIN version:
#
# ```sql
# SELECT DISTINCT c.*
# FROM customers c
# INNER JOIN orders o
# ON c.customer_id = o.customer_id;
# ```
#
# 📌 JOIN is often clearer and faster.
#
# ---
#
# # 🔥 Execution Order with Subqueries
#
# 1. Inner query runs first
# 2. Result passed to outer query
# 3. Outer query executes
