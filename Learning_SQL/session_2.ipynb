# %% [markdown]
# # 🧩 SESSION 2: Database Concepts & How Data Is Stored
#
#
# 🎯 **Goal:** Understand **how data lives inside a database** so SQL actually makes sense
#
#
#
# ---
#
# ## 1️⃣ What Is a Database
#
#
# A **database** is an organized place where data is stored **in tables**, so computers can:
#
# * Find data fast
# * Keep data safe
# * Handle millions of records
#
# 📌 Think: **Excel workbook**, but:
#
# * Much faster
# * Much safer
# * Much bigger
# * Used by many users at once
#
# ---
#
# ## 2️⃣ Database → Table → Row → Column (Hierarchy)
#
# ### 🔹 The Structure (Very Important)
#
# ```
# Database
#  └── Tables
#       ├── Rows (records)
#       └── Columns (fields)
# ```
#
# ---
#
# ### 🔹 Real Example (Company Data)
#
# **Database:** `company_db`
#
# **Table:** `employees`
#
# | emp_id | name | department | salary | city   |
# | ------ | ---- | ---------- | ------ | ------ |
# | 1      | Amit | IT         | 60000  | Delhi  |
# | 2      | Sara | HR         | 50000  | Mumbai |
#
# * **Row** → One employee
# * **Column** → One attribute of employee
#
# 📌 SQL always works on **tables**, not files.
#
# ---
#
# ## 3️⃣ What Is a Table (Deep Understanding)
#
# A **table** is:
#
# * Structured
# * Has fixed columns
# * Each row follows the same structure
#
# ### 🔹 Table Rules
#
# * Every row has the same columns
# * Column data types are fixed
# * Rows can grow to millions
#
# 📌 Interview tip:
#
# > “A table represents an entity (like customer, order, employee).”
#
# ---
#
# ## 4️⃣ Columns & Data Types (VERY IMPORTANT)
#
# ### 🔹 Why Data Types Matter
#
# Data type tells the database:
#
# * What kind of data is stored
#
# * How much space to allocate
#
# * What operations are allowed
#
# ---
#
# ### 🔹 Common SQL Data Types (Must Know)
#
# | Data Type | Meaning         | Example    |
# | --------- | --------------- | ---------- |
# | INT       | Whole numbers   | 25         |
# | FLOAT     | Decimal numbers | 99.5       |
# | VARCHAR   | Text            | "Delhi"    |
# | DATE      | Date            | 2024-01-15 |
# | BOOLEAN   | True/False      | TRUE       |
#
# 📌 Interview question:
# **Why not store numbers as text (VARCHAR)?**
# ✔ Because sorting, math, and performance break.
#
# ---
#
# ## 5️⃣ Primary Key (MOST IMPORTANT CONCEPT)
#
# ### 🔹 What Is a Primary Key?
#
# A **primary key** is a column that:
#
# * Uniquely identifies each row
# * Cannot be NULL
# * Cannot be duplicated
#
# ---
#
# ### 🔹 Example
#
# | emp_id (PK) | name | department |
# | ----------- | ---- | ---------- |
# | 1           | Amit | IT         |
# | 2           | Sara | HR         |
#
# 📌 Even if two people have same name, **ID is unique**.
#
# ---
#
# ### 🔹 Why Primary Key Is Critical
#
# * Helps find rows quickly
# * Required for relationships
# * Prevents duplicate records
#
# 📌 Interview-ready line:
#
# > “Primary keys ensure data integrity and uniqueness.”
#
# ---
#
# ## 6️⃣ Why Databases Don’t Allow “Messy Data”
#
# Databases enforce:
#
# * Fixed structure
# * Valid data types
# * Unique keys
#
# ❌ This is NOT allowed:
#
# * Text in salary column
# * Duplicate primary keys
# * Random columns per row
#
# 📌 This is why databases are trusted.
#
# ---
#
# ## 7️⃣ Real-World Example: Customer Orders
#
# ### Customers Table
#
# | customer_id (PK) | name | city |
# | ---------------- | ---- | ---- |
#
# ### Orders Table
#
# | order_id (PK) | customer_id | order_date | amount |
# | ------------- | ----------- | ---------- | ------ |
#
# 📌 One customer → many orders
# 📌 This concept leads to **JOINs** later
#
# (We’ll go deep into this in future sessions.)
#
# ---
#
# ## 🧪 PRACTICE (THINKING – VERY IMPORTANT)
#
# ### ✍️ Answer in your own words:
#
# 1. What is the difference between database and table?
# 2. What does one row represent?
# 3. Why do columns have data types?
# 4. Why is primary key necessary?
# 5. Can two rows have the same primary key? Why?
#
# 👉 If you struggle, re-read — this is foundational.
#
# ---
#
# ## 🧠 Mini Analyst Exercise
#
# Imagine you’re designing a table for **students**.
#
# Answer:
#
# * What is the table name?
# * What columns would you create?
# * Which column should be the primary key?
# * What data type for marks?
