# %% [markdown]
# # 🧩 SESSION 1: What SQL Is & How Analysts Use It
#
# 🎯 **Goal:** Build *mental clarity* before touching syntax
#
# > ⚠️ Most beginners rush to write queries.
# > Professionals first understand **WHY SQL exists and HOW it’s used at work**.
#
# ---
#
# ## 1️⃣ What Is SQL (From Absolute Scratch)
#
# ### 🔹 Definition (Simple, Interview-Safe)
#
# **SQL (Structured Query Language)** is used to:
#
# * Store data
# * Retrieve data
# * Modify data
# * Delete data
#   from a **database**
#
# 📌 SQL does **NOT** analyze data
# 📌 SQL does **NOT** create charts
# 📌 SQL **EXTRACTS the right data**
#
# ---
#
# ### 🔹 Think of SQL Like This
#
# * Excel → You manually scroll & filter
# * SQL → You **ask questions** and get answers instantly
#
# Example (don’t worry about syntax yet):
#
# > “Give me all employees earning more than 50,000 from IT department.”
#
# That question → SQL query.
#
# ---
#
# ## 2️⃣ Why SQL Is Mandatory for Data Analysts
#
# ### 🔹 Real Company Reality
#
# Companies store data in:
#
# * Databases (PostgreSQL, MySQL, SQL Server, etc.)
# * NOT Excel
# * NOT CSV files
#
# 📌 Your job as an analyst:
#
# 1. Use SQL to **pull data**
# 2. Use Python/Excel to **analyze**
# 3. Use charts to **explain**
#
# ---
#
# ### 🔹 Typical Analyst Workflow (VERY IMPORTANT)
#
# ```
# Database (SQL)
#      ↓
# SQL Query
#      ↓
# Clean Dataset
#      ↓
# Python / Excel
#      ↓
# Visualization
#      ↓
# Business Insight
# ```
#
# 📌 **SQL is always the first step**
#
# ---
#
# ## 3️⃣ SQL vs Excel vs Python (Clear Comparison)
#
# | Tool   | Used For                | Limit             |
# | ------ | ----------------------- | ----------------- |
# | Excel  | Small data, manual work | Slow, error-prone |
# | SQL    | Extracting data         | No charts         |
# | Python | Analysis & automation   | Needs data first  |
#
# 📌 Interview-ready line:
#
# > “SQL is used to retrieve data, Python is used to analyze it.”
#
# ---
#
# ## 4️⃣ What Kind of Questions SQL Answers (Job-Oriented)
#
# SQL helps answer questions like:
#
# * How many customers do we have?
# * What is total sales last month?
# * Which city has highest revenue?
# * Who are the top 10 customers?
# * Which products are loss-making?
#
# 📌 These are **business questions**, not coding questions.
#
# ---
#
# ## 5️⃣ What SQL Is NOT (Common Beginner Confusion)
#
# ❌ SQL is NOT programming like Python
# ❌ SQL does NOT use loops like `for`
# ❌ SQL does NOT create ML models
#
# SQL is **declarative**:
#
# > You say *WHAT* you want, not *HOW* to do it.
#
# ---
#
# ## 6️⃣ How Interviewers Judge SQL Skills
#
# They don’t care about:
# ❌ memorizing syntax
# ❌ fancy queries
#
# They care about:
#
# ✅ logical thinking
#
# ✅ correct filtering
#
# ✅ correct aggregation
#
# ✅ safe queries
#
# ---
#
# ## 7️⃣ Analyst Mindset (CRITICAL)
#
# Before writing any SQL, always ask:
#
# 1. What table has my data?
# 2. What columns do I need?
# 3. What condition filters rows?
# 4. What final output is expected?
#
# 📌 SQL = **thinking clearly, not typing fast**
#
# ---
#
# ## 🧪 PRACTICE (NO CODING YET – THINKING PRACTICE)
#
# ### ✍️ Answer these in words (very important):
#
# 1. Why do companies prefer SQL databases over Excel?
# 2. Where does SQL fit in the data analytics workflow?
# 3. Can SQL replace Python? Why or why not?
# 4. What kind of questions does SQL answer best?
#
# 👉 If you can explain this **out loud**, you are learning correctly.
#
# ---
#
# ## 🧠 Mini Mental Exercise (Interview Style)
#
# Imagine a company asks:
#
# > “We want total sales by city for last 3 months.”
#
# Answer verbally:
#
# * Would you use SQL or Python first?
# * Why?
#
# (Expected answer: SQL first, because data is stored in database.)
#
# ---
